# %% [markdown]
# # Práctica RL - Parte 3
#
# Ejecución completa en Colab con semilla fija `SEED=2024`.

# %%
import os
# Si se ejecuta en Colab, clona rama ADRIAN y prepara dependencias.
if 'COLAB_GPU' in os.environ:
    # !git clone -b ADRIAN https://github.com/fraycarmona/eml_tabular_grupo_17.git
    # %cd /content/eml_tabular_grupo_17/src/EntornosComplejos
    # !pip install -q -r requirements.txt

SEED = 2024
import random
import numpy as np
import torch

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
print('Semilla fijada:', SEED)

# %%
# %run estudiosarsa.ipynb

# %%
# %run estudiodqn.ipynb
